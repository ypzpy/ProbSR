# %%
import os
os.environ['OMP_NUM_THREADS']='2'
os.environ['LD_LIBRARY_PATH']=''
os.environ['CUDA_LAUNCH_BLOCKING']='1'

# %%
# %cd /home/pengyu.zhang/project/superres/ProbSR/Experiment1
# Out:
# /home/pengyu.zhang/project/superres/ProbSR/Experiment1

# %%
from data_generation import *
from scipy.linalg import sqrtm
from downscaling import *
from utils import *
import random

# %%
# %cd Bicubic_Downsampling
# Out:
# /home/pengyu.zhang/project/superres/ProbSR/Experiment1/Bicubic_Downsampling

# %% [markdown]
# ## Langevin & Training Downscale Network

# %% [markdown]
# ### Upscale By 4

# %%
N_low = 40
N_high = 160
scale = 4

h_low = 1/(N_low-1)
x_low = np.arange(0,1.0001,h_low)
y_low = np.arange(0,1.0001,h_low)

h_high = 1/(N_high-1)
x_high = np.arange(0,1.0001,h_high)
y_high = np.arange(0,1.0001,h_high)

# %%
A_high = create_A(N_high)
A_low = create_A(N_low)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Parameters for prior variance
prior_sigma = 0.002
ll_sigma = 0.002

# %%
A_high = torch.tensor(create_A(N_high)).to(torch.float32).to(device)

# %%
A_high = A_high.to_sparse()
operator = (A_high.T) * (1/prior_sigma**2)

# %%
dataset = DataFromH5File4("/home/pengyu.zhang/project/superres/ProbSR/Experiment1/data/40_160_low_forcing.h5")

trainset = random.sample(range(0, 128), 100)
testset = [i for i in range(0,128) if i not in trainset]

# %%
def sample_data():
    coefficient = random.sample(trainset,1)[0]
    forcing = dataset[coefficient][0]
    lr = dataset[coefficient][1]
    
    return forcing, lr


def sample_p_0(x):
    # Randomly sampling for initialisation of the Langevin dynamics
    # prior = torch.randn(*[batch_size,1,20,20]).to(device)
    
    # Set the u_low_mean to the initialisation of the Langevin dynamics
    # posterior_initial = torch.randn([N_high,N_high]).to(torch.float32)
    # posterior_initial = torch.tensor(posterior_initial).to(device).to(torch.float32)
    posterior_initial  = F.interpolate(x.reshape(1,1,N_low,N_low),(N_high,N_high),mode="bicubic").reshape(N_high,N_high)
    
    return posterior_initial

    
def ula_posterior_preconditioner(z, b_high, x, G):
    """
    Langevin dynamics with preconditioner
    """
    z = z.clone().detach().requires_grad_(True)
    sum = 0
    for i in range(K):
        # Grad log-likelihood
        downscaled = F.interpolate(z.reshape(1,1,N_high,N_high),(N_low,N_low)).reshape(N_low,N_low)
        x_hat = downscaled + G(downscaled.reshape(1,N_low,N_low)).reshape(N_low,N_low)
        log_likelihood = (-1/(2*math.pow(ll_sigma, 2)) * torch.matmul((x-x_hat).reshape(1,N_low**2),(x-x_hat).reshape(N_low**2,1)))
        grad_ll = torch.autograd.grad(log_likelihood, z)[0]

        # Grad prior
        difference = torch.spmm(A_high,z.reshape(N_high*N_high,1)) - b_high.reshape(N_high**2,1)
        # log_prior = - 0.5 * difference.T @ G_inverse @ difference
        # grad_log_prior = torch.autograd.grad(log_prior, z)[0]
        grad_log_prior = (- torch.spmm(operator,difference)).reshape(N_high,N_high)
        
        # Random noise term
        W = torch.randn(*[N_high,N_high]).to(device)
        # random = torch.matmul(G_sqrt,W.reshape(N_high**2,1)).reshape(N_high,N_high)
        
        z = z + 0.5 * s ** 2 * grad_log_prior + 0.5 * s ** 2 * grad_ll + s * W
        
        if i >= K - 10:
            sum += z

    sum /= 10
           
    return sum.detach()

# %%
# Train with sampled data
epoch_num = 2000
lr = 0.001
gamma = 0.5

K = 100
s = 0.0004
step_size = 300
minimum_loss = float('inf')
loss_track = []

G = ResidualLearning()
G.apply(weights_init_xavier).to(device)
mse = nn.MSELoss(reduction='sum')
optG = torch.optim.Adam(G.parameters(), lr = lr, weight_decay=0, betas=(0.5, 0.999))
r_scheduleG = torch.optim.lr_scheduler.StepLR(optG, step_size=step_size, gamma=gamma)

# Logger info
dir_name = f'models/model3/40_160/lr{lr}_gamma{gamma}_stepsize{step_size}_K{K}_llsigma_{ll_sigma}_psigma_{prior_sigma}'
makedir(dir_name)
logger = setup_logging('job0', dir_name, console=True)
logger.info(f'Training for {epoch_num} epoches and learning rate is {lr}')

for epoch in range(1, epoch_num+1):
    
    b_high, low_res = sample_data()
    b_high = torch.tensor(b_high).to(torch.float32).to(device)
    low_res = torch.tensor(low_res).to(torch.float32).to(device)
    
    posterior_initial = sample_p_0(low_res)
    posterior_final = ula_posterior_preconditioner(posterior_initial, b_high, low_res, G)

    optG.zero_grad()
    
    downscaled = F.interpolate(posterior_final.reshape(1,1,N_high,N_high),(N_low,N_low)).reshape(1,N_low,N_low)
    out = G(downscaled.reshape(1,N_low,N_low)) + downscaled
    loss = mse(out,low_res.reshape(1,N_low,N_low))
        
    loss.backward()
    optG.step()
    
    if loss < minimum_loss:
        save_model(dir_name, epoch, 'best_model', r_scheduleG, G, optG)
        minimum_loss = loss
            
    if epoch%100 == 0:
        save_model(dir_name, epoch, 'model_epoch_{}'.format(epoch), r_scheduleG, G, optG)
    
    save_model(dir_name, epoch, 'current_epoch', r_scheduleG, G, optG)
    loss_track.append(loss.cpu().data.numpy())
    np.save(f'{dir_name}/chains/loss_curve.npy', np.array(loss_track))
    
    print("Epoch:", epoch, "Loss:", loss)

    r_scheduleG.step()
# Out:
# Output directory already exists
# 2024-08-06 10:23:18,351 : Training for 2000 epoches and learning rate is 0.001
# Epoch: 1 Loss: tensor(0.9070, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 2 Loss: tensor(38.1417, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 3 Loss: tensor(0.9186, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 4 Loss: tensor(4.9672, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 5 Loss: tensor(1.9141, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 6 Loss: tensor(0.1964, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 7 Loss: tensor(0.7046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 8 Loss: tensor(0.2651, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 9 Loss: tensor(0.1580, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 10 Loss: tensor(0.2386, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 11 Loss: tensor(0.1227, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 12 Loss: tensor(0.2182, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 13 Loss: tensor(0.5743, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 14 Loss: tensor(0.2045, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 15 Loss: tensor(0.3332, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 16 Loss: tensor(0.0721, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 17 Loss: tensor(0.1508, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 18 Loss: tensor(0.1546, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 19 Loss: tensor(0.1174, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 20 Loss: tensor(0.0307, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 21 Loss: tensor(0.0889, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 22 Loss: tensor(0.1606, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 23 Loss: tensor(0.0605, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 24 Loss: tensor(0.0610, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 25 Loss: tensor(0.0270, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 26 Loss: tensor(0.0307, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 27 Loss: tensor(0.0283, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 28 Loss: tensor(0.0805, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 29 Loss: tensor(0.0351, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 30 Loss: tensor(0.0552, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 31 Loss: tensor(0.0551, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 32 Loss: tensor(0.0467, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 33 Loss: tensor(0.0340, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 34 Loss: tensor(0.0273, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 35 Loss: tensor(0.0217, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 36 Loss: tensor(0.0275, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 37 Loss: tensor(0.0181, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 38 Loss: tensor(0.0430, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 39 Loss: tensor(0.0265, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 40 Loss: tensor(0.0280, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 41 Loss: tensor(0.0583, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 42 Loss: tensor(0.0530, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 43 Loss: tensor(11.8110, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 44 Loss: tensor(13.8861, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 45 Loss: tensor(12.3025, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 46 Loss: tensor(0.4807, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 47 Loss: tensor(2.3395, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 48 Loss: tensor(0.2168, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 49 Loss: tensor(0.6857, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 50 Loss: tensor(36.1089, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 51 Loss: tensor(9.7712, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 52 Loss: tensor(6.5301, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 53 Loss: tensor(0.7575, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 54 Loss: tensor(0.9419, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 55 Loss: tensor(0.7483, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 56 Loss: tensor(0.2664, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 57 Loss: tensor(0.2358, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 58 Loss: tensor(0.1541, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 59 Loss: tensor(0.1556, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 60 Loss: tensor(0.2549, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 61 Loss: tensor(0.1200, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 62 Loss: tensor(0.0972, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 63 Loss: tensor(0.1856, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 64 Loss: tensor(0.0744, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 65 Loss: tensor(0.2385, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 66 Loss: tensor(0.0816, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 67 Loss: tensor(0.0651, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 68 Loss: tensor(0.0791, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 69 Loss: tensor(0.1690, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 70 Loss: tensor(0.0741, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 71 Loss: tensor(0.0826, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 72 Loss: tensor(0.2473, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 73 Loss: tensor(0.2117, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 74 Loss: tensor(0.0785, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 75 Loss: tensor(0.1875, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 76 Loss: tensor(0.0851, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 77 Loss: tensor(0.2467, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 78 Loss: tensor(0.1483, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 79 Loss: tensor(0.2847, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 80 Loss: tensor(0.7793, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 81 Loss: tensor(0.1969, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 82 Loss: tensor(0.0544, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 83 Loss: tensor(0.1362, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 84 Loss: tensor(0.1742, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 85 Loss: tensor(0.1563, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 86 Loss: tensor(0.0805, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 87 Loss: tensor(0.0511, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 88 Loss: tensor(0.0521, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 89 Loss: tensor(0.1820, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 90 Loss: tensor(0.3122, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 91 Loss: tensor(0.0499, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 92 Loss: tensor(0.1021, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 93 Loss: tensor(0.1713, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 94 Loss: tensor(0.1036, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 95 Loss: tensor(0.1246, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 96 Loss: tensor(0.0494, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 97 Loss: tensor(0.0412, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 98 Loss: tensor(0.0418, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 99 Loss: tensor(0.1180, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 100 Loss: tensor(0.1094, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 101 Loss: tensor(0.0824, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 102 Loss: tensor(0.1302, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 103 Loss: tensor(0.0311, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 104 Loss: tensor(0.0508, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 105 Loss: tensor(0.0897, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 106 Loss: tensor(0.0336, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 107 Loss: tensor(0.0339, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 108 Loss: tensor(0.0921, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 109 Loss: tensor(0.0303, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 110 Loss: tensor(0.0375, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 111 Loss: tensor(0.1794, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 112 Loss: tensor(0.0350, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 113 Loss: tensor(0.1341, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 114 Loss: tensor(0.0281, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 115 Loss: tensor(0.1407, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 116 Loss: tensor(0.0275, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 117 Loss: tensor(0.0997, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 118 Loss: tensor(0.0285, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 119 Loss: tensor(0.0253, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 120 Loss: tensor(0.1179, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 121 Loss: tensor(0.0929, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 122 Loss: tensor(0.5248, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 123 Loss: tensor(0.1021, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 124 Loss: tensor(0.0670, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 125 Loss: tensor(0.0905, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 126 Loss: tensor(0.0236, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 127 Loss: tensor(0.0233, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 128 Loss: tensor(0.0212, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 129 Loss: tensor(0.0197, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 130 Loss: tensor(0.0189, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 131 Loss: tensor(0.0201, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 132 Loss: tensor(0.0201, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 133 Loss: tensor(0.0248, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 134 Loss: tensor(0.0446, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 135 Loss: tensor(0.0203, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 136 Loss: tensor(0.0510, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 137 Loss: tensor(0.0423, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 138 Loss: tensor(0.0412, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 139 Loss: tensor(0.0441, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 140 Loss: tensor(0.0198, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 141 Loss: tensor(0.0152, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 142 Loss: tensor(0.0171, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 143 Loss: tensor(0.0154, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 144 Loss: tensor(0.0347, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 145 Loss: tensor(0.0159, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 146 Loss: tensor(0.0308, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 147 Loss: tensor(0.0275, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 148 Loss: tensor(0.0272, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 149 Loss: tensor(0.0461, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 150 Loss: tensor(0.0629, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 151 Loss: tensor(0.0249, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 152 Loss: tensor(0.0130, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 153 Loss: tensor(0.0134, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 154 Loss: tensor(0.0118, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 155 Loss: tensor(0.0098, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 156 Loss: tensor(0.0105, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 157 Loss: tensor(0.0294, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 158 Loss: tensor(0.0123, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 159 Loss: tensor(0.0262, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 160 Loss: tensor(0.0203, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 161 Loss: tensor(0.0521, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 162 Loss: tensor(0.0241, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 163 Loss: tensor(0.0263, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 164 Loss: tensor(0.0389, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 165 Loss: tensor(0.0180, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 166 Loss: tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 167 Loss: tensor(0.3028, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 168 Loss: tensor(0.0268, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 169 Loss: tensor(0.0399, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 170 Loss: tensor(0.0371, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 171 Loss: tensor(0.0367, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 172 Loss: tensor(0.0196, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 173 Loss: tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 174 Loss: tensor(0.0115, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 175 Loss: tensor(0.0146, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 176 Loss: tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 177 Loss: tensor(0.0318, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 178 Loss: tensor(0.0091, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 179 Loss: tensor(0.0239, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 180 Loss: tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 181 Loss: tensor(0.2389, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 182 Loss: tensor(4.9310, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 183 Loss: tensor(2.4979, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 184 Loss: tensor(8.3338, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 185 Loss: tensor(18.4424, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 186 Loss: tensor(0.1542, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 187 Loss: tensor(2.2863, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 188 Loss: tensor(0.9260, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 189 Loss: tensor(0.0570, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 190 Loss: tensor(0.2995, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 191 Loss: tensor(0.2406, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 192 Loss: tensor(0.2051, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 193 Loss: tensor(0.1346, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 194 Loss: tensor(0.0519, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 195 Loss: tensor(0.2101, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 196 Loss: tensor(0.1894, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 197 Loss: tensor(0.1361, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 198 Loss: tensor(0.0471, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 199 Loss: tensor(0.4797, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 200 Loss: tensor(0.1138, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 201 Loss: tensor(0.0970, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 202 Loss: tensor(0.0374, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 203 Loss: tensor(0.0958, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 204 Loss: tensor(0.0999, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 205 Loss: tensor(0.1382, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 206 Loss: tensor(0.1156, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 207 Loss: tensor(0.0360, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 208 Loss: tensor(0.0349, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 209 Loss: tensor(0.0341, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 210 Loss: tensor(0.2230, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 211 Loss: tensor(0.0331, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 212 Loss: tensor(0.0441, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 213 Loss: tensor(0.0300, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 214 Loss: tensor(0.1602, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 215 Loss: tensor(0.1462, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 216 Loss: tensor(0.0478, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 217 Loss: tensor(0.1942, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 218 Loss: tensor(0.0331, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 219 Loss: tensor(0.0283, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 220 Loss: tensor(0.4931, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 221 Loss: tensor(0.1273, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 222 Loss: tensor(0.1031, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 223 Loss: tensor(0.0295, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 224 Loss: tensor(0.0262, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 225 Loss: tensor(0.0334, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 226 Loss: tensor(0.1527, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 227 Loss: tensor(0.1068, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 228 Loss: tensor(0.0272, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 229 Loss: tensor(0.0987, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 230 Loss: tensor(2.1671, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 231 Loss: tensor(0.1210, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 232 Loss: tensor(0.1462, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 233 Loss: tensor(0.0273, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 234 Loss: tensor(0.1497, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 235 Loss: tensor(0.0700, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 236 Loss: tensor(0.0261, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 237 Loss: tensor(0.0328, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 238 Loss: tensor(0.0786, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 239 Loss: tensor(0.0243, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 240 Loss: tensor(0.0259, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 241 Loss: tensor(0.0239, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 242 Loss: tensor(0.0212, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 243 Loss: tensor(0.0635, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 244 Loss: tensor(0.0206, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 245 Loss: tensor(0.0662, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 246 Loss: tensor(0.0217, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 247 Loss: tensor(0.0581, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 248 Loss: tensor(0.0539, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 249 Loss: tensor(0.0171, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 250 Loss: tensor(0.0526, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 251 Loss: tensor(0.0899, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 252 Loss: tensor(0.0232, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 253 Loss: tensor(0.0461, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 254 Loss: tensor(0.0624, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 255 Loss: tensor(0.0143, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 256 Loss: tensor(0.0462, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 257 Loss: tensor(0.0596, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 258 Loss: tensor(1.6130, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 259 Loss: tensor(0.2970, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 260 Loss: tensor(0.8057, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 261 Loss: tensor(0.0884, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 262 Loss: tensor(0.0682, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 263 Loss: tensor(0.0460, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 264 Loss: tensor(0.0670, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 265 Loss: tensor(0.0424, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 266 Loss: tensor(0.0226, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 267 Loss: tensor(0.0192, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 268 Loss: tensor(0.0555, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 269 Loss: tensor(0.0623, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 270 Loss: tensor(0.0158, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 271 Loss: tensor(0.1218, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 272 Loss: tensor(0.0167, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 273 Loss: tensor(0.0488, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 274 Loss: tensor(0.0166, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 275 Loss: tensor(0.0455, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 276 Loss: tensor(0.0444, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 277 Loss: tensor(0.0412, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 278 Loss: tensor(0.0101, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 279 Loss: tensor(0.3617, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 280 Loss: tensor(0.3003, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 281 Loss: tensor(0.1890, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 282 Loss: tensor(0.0532, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 283 Loss: tensor(0.0133, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 284 Loss: tensor(0.0283, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 285 Loss: tensor(0.0345, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 286 Loss: tensor(0.0104, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 287 Loss: tensor(0.0343, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 288 Loss: tensor(0.0319, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 289 Loss: tensor(0.0293, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 290 Loss: tensor(0.0286, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 291 Loss: tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 292 Loss: tensor(0.0240, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 293 Loss: tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 294 Loss: tensor(0.0275, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 295 Loss: tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 296 Loss: tensor(0.0270, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 297 Loss: tensor(0.9533, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 298 Loss: tensor(0.2348, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 299 Loss: tensor(0.1455, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 300 Loss: tensor(0.0098, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 301 Loss: tensor(0.0532, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 302 Loss: tensor(0.0538, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 303 Loss: tensor(0.0137, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 304 Loss: tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 305 Loss: tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 306 Loss: tensor(0.0101, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 307 Loss: tensor(0.0514, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 308 Loss: tensor(0.0109, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 309 Loss: tensor(0.0352, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 310 Loss: tensor(0.0231, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 311 Loss: tensor(0.0219, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 312 Loss: tensor(0.0209, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 313 Loss: tensor(0.0055, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 314 Loss: tensor(0.0056, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 315 Loss: tensor(0.1385, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 316 Loss: tensor(37.9804, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 317 Loss: tensor(2.8941, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 318 Loss: tensor(2.1427, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 319 Loss: tensor(0.5328, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 320 Loss: tensor(0.7427, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 321 Loss: tensor(1.7823, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 322 Loss: tensor(0.2855, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 323 Loss: tensor(0.3860, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 324 Loss: tensor(0.2668, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 325 Loss: tensor(0.1823, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 326 Loss: tensor(0.2278, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 327 Loss: tensor(1.4142, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 328 Loss: tensor(0.1801, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 329 Loss: tensor(0.0888, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 330 Loss: tensor(0.1399, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 331 Loss: tensor(0.0511, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 332 Loss: tensor(0.0470, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 333 Loss: tensor(22.3973, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 334 Loss: tensor(3.7863, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 335 Loss: tensor(2.8007, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 336 Loss: tensor(0.8233, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 337 Loss: tensor(0.3936, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 338 Loss: tensor(0.1228, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 339 Loss: tensor(0.1775, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 340 Loss: tensor(0.1163, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 341 Loss: tensor(0.6153, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 342 Loss: tensor(0.1413, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 343 Loss: tensor(0.0756, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 344 Loss: tensor(0.2369, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 345 Loss: tensor(0.3192, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 346 Loss: tensor(0.3759, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 347 Loss: tensor(0.3641, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 348 Loss: tensor(0.1441, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 349 Loss: tensor(0.1960, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 350 Loss: tensor(0.0447, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 351 Loss: tensor(0.1014, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 352 Loss: tensor(0.1027, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 353 Loss: tensor(0.1552, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 354 Loss: tensor(0.6312, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 355 Loss: tensor(0.8171, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 356 Loss: tensor(0.2965, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 357 Loss: tensor(1.4228, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 358 Loss: tensor(1.0868, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 359 Loss: tensor(0.1675, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 360 Loss: tensor(0.0478, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 361 Loss: tensor(0.0845, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 362 Loss: tensor(0.2647, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 363 Loss: tensor(0.0546, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 364 Loss: tensor(0.2440, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 365 Loss: tensor(0.2219, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 366 Loss: tensor(0.1572, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 367 Loss: tensor(0.1047, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 368 Loss: tensor(0.0241, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 369 Loss: tensor(0.0667, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 370 Loss: tensor(0.0194, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 371 Loss: tensor(0.0214, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 372 Loss: tensor(0.0203, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 373 Loss: tensor(0.0185, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 374 Loss: tensor(0.0542, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 375 Loss: tensor(0.0963, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 376 Loss: tensor(0.0188, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 377 Loss: tensor(0.0659, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 378 Loss: tensor(0.0164, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 379 Loss: tensor(0.0663, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 380 Loss: tensor(0.1795, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 381 Loss: tensor(0.8486, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 382 Loss: tensor(0.0782, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 383 Loss: tensor(0.0899, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 384 Loss: tensor(0.0395, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 385 Loss: tensor(0.0180, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 386 Loss: tensor(0.0877, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 387 Loss: tensor(0.0110, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 388 Loss: tensor(0.0705, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 389 Loss: tensor(0.0117, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 390 Loss: tensor(0.0201, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 391 Loss: tensor(0.1123, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 392 Loss: tensor(0.0223, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 393 Loss: tensor(0.0126, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 394 Loss: tensor(0.0617, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 395 Loss: tensor(0.0573, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 396 Loss: tensor(0.0438, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 397 Loss: tensor(0.0194, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 398 Loss: tensor(0.0233, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 399 Loss: tensor(0.0263, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 400 Loss: tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 401 Loss: tensor(0.0362, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 402 Loss: tensor(0.0950, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 403 Loss: tensor(0.0199, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 404 Loss: tensor(0.5539, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 405 Loss: tensor(0.0144, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 406 Loss: tensor(0.0214, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 407 Loss: tensor(0.0110, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 408 Loss: tensor(0.0105, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 409 Loss: tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 410 Loss: tensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 411 Loss: tensor(0.0168, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 412 Loss: tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 413 Loss: tensor(0.0061, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 414 Loss: tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 415 Loss: tensor(0.0189, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 416 Loss: tensor(0.0138, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 417 Loss: tensor(0.0108, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 418 Loss: tensor(0.0169, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 419 Loss: tensor(0.0240, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 420 Loss: tensor(0.0051, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 421 Loss: tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 422 Loss: tensor(0.0138, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 423 Loss: tensor(0.0063, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 424 Loss: tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 425 Loss: tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 426 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 427 Loss: tensor(0.0295, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 428 Loss: tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 429 Loss: tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 430 Loss: tensor(0.4123, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 431 Loss: tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 432 Loss: tensor(0.0252, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 433 Loss: tensor(0.0119, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 434 Loss: tensor(0.0063, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 435 Loss: tensor(0.0098, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 436 Loss: tensor(0.0151, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 437 Loss: tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 438 Loss: tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 439 Loss: tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 440 Loss: tensor(0.0120, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 441 Loss: tensor(0.0102, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 442 Loss: tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 443 Loss: tensor(0.0117, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 444 Loss: tensor(0.0204, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 445 Loss: tensor(0.1524, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 446 Loss: tensor(0.0450, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 447 Loss: tensor(0.0133, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 448 Loss: tensor(0.0402, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 449 Loss: tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 450 Loss: tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 451 Loss: tensor(0.0091, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 452 Loss: tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 453 Loss: tensor(0.0093, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 454 Loss: tensor(0.0050, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 455 Loss: tensor(0.0145, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 456 Loss: tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 457 Loss: tensor(0.0153, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 458 Loss: tensor(0.0099, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 459 Loss: tensor(0.0038, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 460 Loss: tensor(0.0135, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 461 Loss: tensor(0.0055, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 462 Loss: tensor(0.0401, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 463 Loss: tensor(0.0041, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 464 Loss: tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 465 Loss: tensor(0.0203, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 466 Loss: tensor(0.0096, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 467 Loss: tensor(0.0050, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 468 Loss: tensor(0.0384, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 469 Loss: tensor(2.7443, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 470 Loss: tensor(0.0794, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 471 Loss: tensor(0.0688, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 472 Loss: tensor(0.0189, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 473 Loss: tensor(0.0216, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 474 Loss: tensor(0.0448, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 475 Loss: tensor(0.0116, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 476 Loss: tensor(0.0051, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 477 Loss: tensor(0.0088, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 478 Loss: tensor(0.0108, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 479 Loss: tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 480 Loss: tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 481 Loss: tensor(0.0042, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 482 Loss: tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 483 Loss: tensor(0.0037, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 484 Loss: tensor(0.0123, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 485 Loss: tensor(0.0103, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 486 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 487 Loss: tensor(0.0037, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 488 Loss: tensor(0.0039, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 489 Loss: tensor(0.0129, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 490 Loss: tensor(0.0101, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 491 Loss: tensor(0.0037, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 492 Loss: tensor(0.0213, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 493 Loss: tensor(0.0039, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 494 Loss: tensor(0.0304, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 495 Loss: tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 496 Loss: tensor(0.0150, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 497 Loss: tensor(0.0157, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 498 Loss: tensor(0.0055, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 499 Loss: tensor(0.0096, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 500 Loss: tensor(0.0187, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 501 Loss: tensor(0.0163, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 502 Loss: tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 503 Loss: tensor(0.0059, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 504 Loss: tensor(0.0112, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 505 Loss: tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 506 Loss: tensor(0.0098, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 507 Loss: tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 508 Loss: tensor(0.0125, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 509 Loss: tensor(0.0112, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 510 Loss: tensor(0.0165, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 511 Loss: tensor(0.0140, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 512 Loss: tensor(0.0037, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 513 Loss: tensor(0.5640, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 514 Loss: tensor(0.0785, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 515 Loss: tensor(0.0487, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 516 Loss: tensor(0.0098, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 517 Loss: tensor(0.0159, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 518 Loss: tensor(0.0195, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 519 Loss: tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 520 Loss: tensor(0.0214, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 521 Loss: tensor(0.0113, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 522 Loss: tensor(0.2955, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 523 Loss: tensor(0.0155, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 524 Loss: tensor(0.0137, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 525 Loss: tensor(0.0061, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 526 Loss: tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 527 Loss: tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 528 Loss: tensor(0.2633, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 529 Loss: tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 530 Loss: tensor(0.0146, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 531 Loss: tensor(0.0096, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 532 Loss: tensor(0.0150, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 533 Loss: tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 534 Loss: tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 535 Loss: tensor(0.0097, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 536 Loss: tensor(0.0052, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 537 Loss: tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 538 Loss: tensor(0.2366, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 539 Loss: tensor(0.0051, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 540 Loss: tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 541 Loss: tensor(0.0059, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 542 Loss: tensor(1.4136, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 543 Loss: tensor(0.0092, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 544 Loss: tensor(0.0090, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 545 Loss: tensor(0.0085, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 546 Loss: tensor(0.0155, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 547 Loss: tensor(0.1384, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 548 Loss: tensor(0.0190, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 549 Loss: tensor(0.0262, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 550 Loss: tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 551 Loss: tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 552 Loss: tensor(0.0192, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 553 Loss: tensor(0.0091, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 554 Loss: tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 555 Loss: tensor(0.0040, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 556 Loss: tensor(0.0255, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 557 Loss: tensor(0.0087, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 558 Loss: tensor(0.0091, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 559 Loss: tensor(0.0088, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 560 Loss: tensor(0.0118, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 561 Loss: tensor(0.0093, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 562 Loss: tensor(0.0186, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 563 Loss: tensor(0.0230, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 564 Loss: tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 565 Loss: tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 566 Loss: tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 567 Loss: tensor(0.0052, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 568 Loss: tensor(0.0101, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 569 Loss: tensor(0.0129, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 570 Loss: tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 571 Loss: tensor(0.0099, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 572 Loss: tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 573 Loss: tensor(0.0116, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 574 Loss: tensor(0.0038, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 575 Loss: tensor(0.0116, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 576 Loss: tensor(0.0278, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 577 Loss: tensor(0.0119, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 578 Loss: tensor(0.0040, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 579 Loss: tensor(0.0040, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 580 Loss: tensor(0.0035, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 581 Loss: tensor(0.7514, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 582 Loss: tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 583 Loss: tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 584 Loss: tensor(0.0154, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 585 Loss: tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 586 Loss: tensor(0.0216, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 587 Loss: tensor(0.0039, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 588 Loss: tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 589 Loss: tensor(0.0118, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 590 Loss: tensor(0.0110, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 591 Loss: tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 592 Loss: tensor(0.0285, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 593 Loss: tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 594 Loss: tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 595 Loss: tensor(0.0040, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 596 Loss: tensor(0.0850, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 597 Loss: tensor(0.0156, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 598 Loss: tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 599 Loss: tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 600 Loss: tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 601 Loss: tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 602 Loss: tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 603 Loss: tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 604 Loss: tensor(0.0038, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 605 Loss: tensor(0.0317, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 606 Loss: tensor(0.0132, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 607 Loss: tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 608 Loss: tensor(0.0108, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 609 Loss: tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 610 Loss: tensor(0.0140, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 611 Loss: tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 612 Loss: tensor(0.0099, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 613 Loss: tensor(0.0125, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 614 Loss: tensor(0.0194, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 615 Loss: tensor(0.0130, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 616 Loss: tensor(0.0262, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 617 Loss: tensor(0.0761, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 618 Loss: tensor(0.0110, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 619 Loss: tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 620 Loss: tensor(0.0148, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 621 Loss: tensor(0.0078, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 622 Loss: tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 623 Loss: tensor(0.0154, device='cuda:0', grad_fn=<MseLossBackward0>)
# ...
# Epoch: 1796 Loss: tensor(0.0033, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1797 Loss: tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1798 Loss: tensor(0.0194, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1799 Loss: tensor(0.0033, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1800 Loss: tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1801 Loss: tensor(0.0027, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1802 Loss: tensor(0.0031, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1803 Loss: tensor(0.0152, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1804 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1805 Loss: tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1806 Loss: tensor(0.0114, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1807 Loss: tensor(0.0074, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1808 Loss: tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1809 Loss: tensor(0.0042, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1810 Loss: tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1811 Loss: tensor(0.0113, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1812 Loss: tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1813 Loss: tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1814 Loss: tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1815 Loss: tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1816 Loss: tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1817 Loss: tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1818 Loss: tensor(0.0052, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1819 Loss: tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1820 Loss: tensor(0.0149, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1821 Loss: tensor(0.0087, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1822 Loss: tensor(0.0197, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1823 Loss: tensor(0.0035, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1824 Loss: tensor(0.0369, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1825 Loss: tensor(0.0033, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1826 Loss: tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1827 Loss: tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1828 Loss: tensor(0.0074, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1829 Loss: tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1830 Loss: tensor(0.0029, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1831 Loss: tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1832 Loss: tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1833 Loss: tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1834 Loss: tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1835 Loss: tensor(0.0027, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1836 Loss: tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1837 Loss: tensor(0.0096, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1838 Loss: tensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1839 Loss: tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1840 Loss: tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1841 Loss: tensor(0.0032, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1842 Loss: tensor(0.0101, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1843 Loss: tensor(0.0088, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1844 Loss: tensor(0.0087, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1845 Loss: tensor(0.0042, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1846 Loss: tensor(0.0040, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1847 Loss: tensor(0.0145, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1848 Loss: tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1849 Loss: tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1850 Loss: tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1851 Loss: tensor(0.0034, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1852 Loss: tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1853 Loss: tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1854 Loss: tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1855 Loss: tensor(0.0035, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1856 Loss: tensor(0.0034, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1857 Loss: tensor(0.0115, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1858 Loss: tensor(0.0235, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1859 Loss: tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1860 Loss: tensor(0.0027, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1861 Loss: tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1862 Loss: tensor(0.0450, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1863 Loss: tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1864 Loss: tensor(0.0059, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1865 Loss: tensor(0.0074, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1866 Loss: tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1867 Loss: tensor(0.0236, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1868 Loss: tensor(0.0029, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1869 Loss: tensor(0.0033, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1870 Loss: tensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1871 Loss: tensor(0.0437, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1872 Loss: tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1873 Loss: tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1874 Loss: tensor(0.0074, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1875 Loss: tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1876 Loss: tensor(0.0029, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1877 Loss: tensor(0.0035, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1878 Loss: tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1879 Loss: tensor(0.0027, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1880 Loss: tensor(0.0092, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1881 Loss: tensor(0.0029, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1882 Loss: tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1883 Loss: tensor(0.0063, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1884 Loss: tensor(0.0027, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1885 Loss: tensor(0.0109, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1886 Loss: tensor(0.0029, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1887 Loss: tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1888 Loss: tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1889 Loss: tensor(0.0109, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1890 Loss: tensor(0.0026, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1891 Loss: tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1892 Loss: tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1893 Loss: tensor(0.0104, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1894 Loss: tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1895 Loss: tensor(0.0235, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1896 Loss: tensor(0.0055, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1897 Loss: tensor(0.0031, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1898 Loss: tensor(0.0124, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1899 Loss: tensor(0.0041, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1900 Loss: tensor(0.0092, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1901 Loss: tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1902 Loss: tensor(0.0042, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1903 Loss: tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1904 Loss: tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1905 Loss: tensor(0.0126, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1906 Loss: tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1907 Loss: tensor(0.0104, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1908 Loss: tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1909 Loss: tensor(0.0034, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1910 Loss: tensor(0.1916, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1911 Loss: tensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1912 Loss: tensor(0.0060, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1913 Loss: tensor(0.0034, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1914 Loss: tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1915 Loss: tensor(0.0389, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1916 Loss: tensor(0.0119, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1917 Loss: tensor(0.0059, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1918 Loss: tensor(0.0059, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1919 Loss: tensor(0.0034, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1920 Loss: tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1921 Loss: tensor(0.0033, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1922 Loss: tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1923 Loss: tensor(0.0068, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1924 Loss: tensor(0.0085, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1925 Loss: tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1926 Loss: tensor(0.0032, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1927 Loss: tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1928 Loss: tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1929 Loss: tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1930 Loss: tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1931 Loss: tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1932 Loss: tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1933 Loss: tensor(0.0034, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1934 Loss: tensor(0.0041, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1935 Loss: tensor(0.0103, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1936 Loss: tensor(0.0035, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1937 Loss: tensor(0.0029, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1938 Loss: tensor(0.0029, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1939 Loss: tensor(0.0059, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1940 Loss: tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1941 Loss: tensor(0.0233, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1942 Loss: tensor(0.0032, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1943 Loss: tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1944 Loss: tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1945 Loss: tensor(0.0034, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1946 Loss: tensor(0.0442, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1947 Loss: tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1948 Loss: tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1949 Loss: tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1950 Loss: tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1951 Loss: tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1952 Loss: tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1953 Loss: tensor(0.0088, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1954 Loss: tensor(0.0375, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1955 Loss: tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1956 Loss: tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1957 Loss: tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1958 Loss: tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1959 Loss: tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1960 Loss: tensor(0.0114, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1961 Loss: tensor(0.0032, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1962 Loss: tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1963 Loss: tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1964 Loss: tensor(0.0114, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1965 Loss: tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1966 Loss: tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1967 Loss: tensor(0.0033, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1968 Loss: tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1969 Loss: tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1970 Loss: tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1971 Loss: tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1972 Loss: tensor(0.0104, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1973 Loss: tensor(0.0032, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1974 Loss: tensor(0.0373, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1975 Loss: tensor(0.0037, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1976 Loss: tensor(0.0061, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1977 Loss: tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1978 Loss: tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1979 Loss: tensor(0.0060, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1980 Loss: tensor(0.0061, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1981 Loss: tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1982 Loss: tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1983 Loss: tensor(0.0034, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1984 Loss: tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1985 Loss: tensor(0.0101, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1986 Loss: tensor(0.0080, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1987 Loss: tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1988 Loss: tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1989 Loss: tensor(0.0371, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1990 Loss: tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1991 Loss: tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1992 Loss: tensor(0.0068, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1993 Loss: tensor(0.0034, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1994 Loss: tensor(0.0124, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1995 Loss: tensor(0.0060, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1996 Loss: tensor(0.0034, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1997 Loss: tensor(0.0027, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1998 Loss: tensor(0.0027, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 1999 Loss: tensor(0.0029, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 2000 Loss: tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward0>)

# %% [markdown]
# ### Upscale By 6

# %%
N_low = 21
N_high = 121
scale = 6

h_low = 1/(N_low-1)
x_low = np.arange(0,1.0001,h_low)
y_low = np.arange(0,1.0001,h_low)

h_high = 1/(N_high-1)
x_high = np.arange(0,1.0001,h_high)
y_high = np.arange(0,1.0001,h_high)

A_high = create_A(N_high)
A_low = create_A(N_low)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Parameters for prior variance
prior_sigma = 0.002
ll_sigma = 0.006

# %%
# Define prior variance
G = np.eye(N_high**2) * prior_sigma**2
G_inverse = np.eye(N_high**2) * (1/prior_sigma**2)

# Turn matrices to tensors
G = torch.tensor(G).to(torch.float32).to(device)
G_inverse = torch.tensor(G_inverse).to(torch.float32).to(device)
A_high = torch.tensor(create_A(N_high)).to(torch.float32).to(device)

# Store sparse matrices as sparse tensor
A_high = A_high.to_sparse()
G = G.to_sparse()
G_inverse = G_inverse.to_sparse()
operator = torch.spmm(A_high.T,G_inverse).to(device)

# %%
dataset = DataFromH5File4("/home/pz281@ad.eng.cam.ac.uk/mnt/PhD/Pro_Down_SR/data/21_121_low_forcing.h5")

trainset = random.sample(range(0, 128), 100)
testset = [i for i in range(0,128) if i not in trainset]

# %%
def sample_data():
    coefficient = random.sample(trainset,1)[0]
    forcing = dataset[coefficient][0]
    lr = dataset[coefficient][1]
    
    return forcing, lr


def sample_p_0():
    # Randomly sampling for initialisation of the Langevin dynamics
    # prior = torch.randn(*[batch_size,1,20,20]).to(device)
    
    # Set the u_low_mean to the initialisation of the Langevin dynamics
    posterior_initial = torch.randn([N_high,N_high]).to(torch.float32)
    posterior_initial = torch.tensor(posterior_initial).to(device).to(torch.float32)
    
    return posterior_initial

    
def ula_posterior_preconditioner(z, b_high, x, G):
    """
    Langevin dynamics with preconditioner
    """
    z = z.clone().detach().requires_grad_(True)
    for i in range(K):
        # Grad log-likelihood
        downscaled = F.interpolate(z.reshape(1,1,N_high,N_high),(N_low,N_low)).reshape(N_low,N_low)
        x_hat = downscaled + G(downscaled.reshape(1,N_low,N_low)).reshape(N_low,N_low)
        log_likelihood = (-1/(2*math.pow(ll_sigma, 2)) * torch.matmul((x-x_hat).reshape(1,N_low**2),(x-x_hat).reshape(N_low**2,1)))
        grad_ll = torch.autograd.grad(log_likelihood, z)[0]

        # Grad prior
        difference = torch.spmm(A_high,z.reshape(N_high*N_high,1)) - b_high.reshape(N_high**2,1)
        # log_prior = - 0.5 * difference.T @ G_inverse @ difference
        # grad_log_prior = torch.autograd.grad(log_prior, z)[0]
        grad_log_prior = (- torch.spmm(operator,difference)).reshape(N_high,N_high)
        
        # Random noise term
        W = torch.randn(*[N_high,N_high]).to(device)
        # random = torch.matmul(G_sqrt,W.reshape(N_high**2,1)).reshape(N_high,N_high)
        
        z = z + 0.5 * s ** 2 * grad_log_prior + 0.5 * s ** 2 * grad_ll + s * W
        # chains_evolution.append(z.cpu().data.numpy())   
           
    return z.detach()

# %%
# Train with sampled data
epoch_num = 1000
lr = 0.005
gamma = 0.5
step_size = 30
minimum_loss = float('inf')
loss_track = []

K = 10000
s = 0.0004

G = ResidualLearning()
G.apply(weights_init_xavier).to(device)
mse = nn.MSELoss(reduction='sum')
optG = torch.optim.Adam(G.parameters(), lr = lr, weight_decay=0, betas=(0.5, 0.999))
r_scheduleG = torch.optim.lr_scheduler.StepLR(optG, step_size=step_size, gamma=gamma)

# Logger info
dir_name = f'models/model3/21_121/lr{lr}_gamma{gamma}_stepsize{step_size}_K{K}'
makedir(dir_name)
logger = setup_logging('job0', dir_name, console=True)
logger.info(f'Training for {epoch_num} epoches and learning rate is {lr}')

for epoch in range(1, epoch_num+1):
    
    b_high, low_res = sample_data()
    b_high = torch.tensor(b_high).to(torch.float32).to(device)
    low_res = torch.tensor(low_res).to(torch.float32).to(device)
    
    posterior_initial = sample_p_0()
    posterior_final = ula_posterior_preconditioner(posterior_initial, b_high, low_res, G)

    optG.zero_grad()
    
    downscaled = F.interpolate(posterior_final.reshape(1,1,N_high,N_high),(N_low,N_low)).reshape(1,N_low,N_low)
    out = G(downscaled.reshape(1,N_low,N_low)) + downscaled
    loss = mse(out,low_res.reshape(1,N_low,N_low))
        
    loss.backward()
    optG.step()
    
    if loss < minimum_loss:
        save_model(dir_name, epoch, 'best_model', r_scheduleG, G, optG)
        minimum_loss = loss
            
    if epoch%100 == 0:
        save_model(dir_name, epoch, 'model_epoch_{}'.format(epoch), r_scheduleG, G, optG)
        
    save_model(dir_name, epoch, 'current_epoch', r_scheduleG, G, optG)
        
    loss_track.append(loss.cpu().data.numpy())
    np.save(f'{dir_name}/chains/loss_curve.npy', np.array(loss_track))
    
    print("Epoch:", epoch, "Loss:", loss)

    r_scheduleG.step()
# Out:
# 2024-06-03 13:45:19,851 : Training for 1000 epoches and learning rate is 0.005
# /tmp/ipykernel_12620/2123801182.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   posterior_initial = torch.tensor(posterior_initial).to(device).to(torch.float32)
# Epoch: 1 Loss: tensor(4.8323, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 2 Loss: tensor(1.6451, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 3 Loss: tensor(5.1077, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 4 Loss: tensor(2.2748, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 5 Loss: tensor(0.8231, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 6 Loss: tensor(2.1439, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 7 Loss: tensor(0.5367, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 8 Loss: tensor(0.9620, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 9 Loss: tensor(5.6040, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 10 Loss: tensor(2.0077, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 11 Loss: tensor(15.0155, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 12 Loss: tensor(0.7064, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 13 Loss: tensor(0.5590, device='cuda:0', grad_fn=<MseLossBackward0>)
# Epoch: 14 Loss: tensor(7.4551, device='cuda:0', grad_fn=<MseLossBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 31
#      28 low_res = torch.tensor(low_res).to(torch.float32).to(device)
#      30 posterior_initial = sample_p_0()
# ---> 31 posterior_final = ula_posterior_preconditioner(posterior_initial, b_high, low_res, G)
#      33 optG.zero_grad()
#      35 downscaled = F.interpolate(posterior_final.reshape(1,1,N_high,N_high),(N_low,N_low)).reshape(1,N_low,N_low)
#
# Cell In[34], line 42, in ula_posterior_preconditioner(z, b_high, x, G)
#      39     W = torch.randn(*[N_high,N_high]).to(device)
#      40     # random = torch.matmul(G_sqrt,W.reshape(N_high**2,1)).reshape(N_high,N_high)
# ---> 42     z = z + 0.5 * s ** 2 * grad_log_prior + 0.5 * s ** 2 * grad_ll + s * W
#      43     # chains_evolution.append(z.cpu().data.numpy())
#      45 return z.detach()
#
# KeyboardInterrupt:
