# %%
import os
os.environ['OMP_NUM_THREADS']='2'
os.environ['LD_LIBRARY_PATH']=''
os.environ['CUDA_LAUNCH_BLOCKING']='1'

# %%
# %cd /home/pengyu.zhang/project/superres/ProbSR/Experiment1
# Out:
# /home/pengyu.zhang/project/superres/ProbSR/Experiment1

# %%
from data_generation import *
from scipy.linalg import sqrtm
from downscaling import *
from utils import *
import random
import torch.nn.functional as F

# %%
# %cd Matrix_Downsampling/
# Out:
# /home/pengyu.zhang/project/superres/ProbSR/Experiment1/Matrix_Downsampling

# %% [markdown]
# ## Train Downscaling Network

# %% [markdown]
# ### Model 1: Training $u_l=G(u_h)$

# %% [markdown]
# ### Model 2: Training $u_l=Hu_h+G(u_h)$

# %% [markdown]
# ### Model 3: Training $u_l = Hu_h + G(Hu_h)$

# %%
# Code downscaling matrix
N_low = 41
N_high = 161
scale = 4

H = np.zeros((N_low*N_low, N_high*N_high))

submatrix = np.zeros((N_low,N_high))
for i in range(N_low):
    submatrix[i,scale*i] = 1
    
for j in range(N_low):
    H[N_low*j:N_low*(j+1),N_high*scale*j:N_high*(scale*j+1)] = submatrix
    
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
H = torch.tensor(H).to(torch.float32).to(device)
H = H.to_sparse()

# %%
epoch_num = 1000
batch_size = 8
lr = 0.01
gamma = 0.5

minimum_loss = float('inf')
loss_track = []

# Load training data
trainset = DataFromH5File3("/home/pengyu.zhang/project/superres/ProbSR/Experiment1/data/DownBy4_41_161.h5",N_low,N_high,scale)
train_loader = data.DataLoader(dataset=trainset, batch_size=batch_size, shuffle=True)

# Initialise training model
G = ResidualLearning()
G.apply(weights_init_xavier).to(device)
mse = nn.MSELoss(reduction='sum')
optG = torch.optim.Adam(G.parameters(), lr = lr, weight_decay=0, betas=(0.5, 0.999))
r_scheduleG = torch.optim.lr_scheduler.StepLR(optG, step_size=50, gamma=gamma)

# Logger info
dir_name = f'models/train_NN/model3/41_161/lr{lr}_gamma{gamma}'
makedir(dir_name)
logger = setup_logging('job0', dir_name, console=True)
logger.info(f'Training for {epoch_num} epoches and learning rate is {lr}')

for epoch in range(1, epoch_num+1):
    
    for i, d in enumerate(train_loader, 0):
        
        residual, observation, low_res = d
        size = residual.shape[0]
        low_res = low_res.to(device).reshape(size,1,N_low,N_low)
        residual = residual.to(device).reshape(size,1,N_low,N_low)
        observation = observation.to(device).reshape(size,1,N_low,N_low)
        
        optG.zero_grad()
        out = G(observation)
        loss = mse(out,residual)/batch_size
        loss.backward()
        optG.step()
        
        if loss < minimum_loss:
            save_model(dir_name, epoch, 'best_model', r_scheduleG, G, optG)
            minimum_loss = loss
            
        if epoch%100 == 0:
            save_model(dir_name, epoch, 'model_epoch_{}'.format(epoch), r_scheduleG, G, optG)
            
        loss_track.append(loss.cpu().data.numpy())
        np.save(f'{dir_name}/chains/loss_curve.npy', np.array(loss_track))
        
        print("Epoch:", epoch, "Loss:", loss)

    r_scheduleG.step()

# %%
N_low = 41
N_high = 161
scale = 4
a, b, c = 4,5,5

h_low = 1/(N_low-1)
x_low = np.arange(0,1.0001,h_low)
y_low = np.arange(0,1.0001,h_low)

h_high = 1/(N_high-1)
x_high = np.arange(0,1.0001,h_high)
y_high = np.arange(0,1.0001,h_high)

# %%
w_low, r_low, A_low, x_low, y_low = generate_data(N_low,a,b,c)
w_high, r_high, A_high, x_high, y_high = generate_data(N_high,a,b,c)

# Code downscaling matrix
H = np.zeros((N_low*N_low, N_high*N_high))

submatrix = np.zeros((N_low,N_high))
for i in range(N_low):
    submatrix[i,scale*i] = 1
    
for j in range(N_low):
    H[N_low*j:N_low*(j+1),N_high*scale*j:N_high*(scale*j+1)] = submatrix

# %%
G = ResidualLearning().to(device)
G.load_state_dict(torch.load('models/train_NN/model3/41_161/lr0.01_gamma0.5/ckpt/best_model.pth')['netG'])
# Out:
# <All keys matched successfully>

# %%
observation = (H @ w_high.reshape(N_high**2,1)).reshape(N_low,N_low)
out = G(torch.tensor(observation).to(device).reshape(1,N_low,N_low).to(torch.float32))
residual = w_low-(H@w_high.reshape(N_high*N_high)).reshape(N_low,N_low)

# %%
fig = plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
plt.pcolormesh(x_low, y_low, residual, cmap='rainbow')
cbar = plt.colorbar(pad=0.05, aspect=10)
cbar.mappable.set_clim(-0.03, 0.03)
plt.title('LR')
plt.xlabel('x')
plt.ylabel('y')
plt.subplot(1,2,2)
plt.pcolormesh(x_low, y_low, out.cpu().data.numpy()[0], cmap='rainbow')
cbar = plt.colorbar(pad=0.05, aspect=10)
cbar.mappable.set_clim(-0.03, 0.03)
plt.title('LR')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### Upscale by 4

# %%
N_low = 41
N_high = 161
scale = 4
a,b,c = 4,5,5

h_low = 1/(N_low-1)
x_low = np.arange(0,1.0001,h_low)
y_low = np.arange(0,1.0001,h_low)

h_high = 1/(N_high-1)
x_high = np.arange(0,1.0001,h_high)
y_high = np.arange(0,1.0001,h_high)

# %%
w_low, r_low, A_low, x_low, y_low = generate_data(N_low,a,b,c)
w_high, r_high, A_high, x_high, y_high = generate_data(N_high,a,b,c)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Parameters for RBF kernal
prior_sigma = 0.002
ll_sigma = 0.001

# %%
# Code downscaling matrix
H = np.zeros((N_low*N_low, N_high*N_high))

submatrix = np.zeros((N_low,N_high))
for i in range(N_low):
    submatrix[i,scale*i] = 1
    
for j in range(N_low):
    H[N_low*j:N_low*(j+1),N_high*scale*j:N_high*(scale*j+1)] = submatrix
    
H = torch.tensor(H).to(device).to(torch.float32)
H = H.to_sparse()

# %%
A_high = csr_matrix(A_high)

# %%
operator = (A_high.T) * (1/prior_sigma**2)
b_high = create_forcing_term(N_high,a,b,c)

# %%
G = ResidualLearning().to(device)
G.load_state_dict(torch.load('models/train_NN/model3/41_161/lr0.01_gamma0.5/ckpt/best_model.pth')['netG'])
# Out:
# <All keys matched successfully>

# %%
# Parameters for Langevin dynamics
K = 100
s = 0.0004

x = torch.tensor(w_low).to(torch.float32).to(device)
#posterior_initial = torch.randn(*[N_high,N_high]).to(torch.float32).to(device)
#z = posterior_initial
z = F.interpolate(x.reshape(1,1,N_low,N_low),(N_high,N_high)).reshape(N_high,N_high)
chains_evolution = []
z = z.clone().detach().requires_grad_(True)
for i in range(K):
    # Grad log-likelihood
    observation = torch.spmm(H,z.reshape(N_high*N_high,1)).reshape(N_low,N_low)
    x_hat = observation + G(observation.reshape(1,N_low,N_low)).reshape(N_low,N_low)
    log_likelihood = (-1/(2*math.pow(ll_sigma, 2)) * torch.matmul((x-x_hat).reshape(1,N_low**2),(x-x_hat).reshape(N_low**2,1)))
    grad_ll = torch.autograd.grad(log_likelihood, z)[0]
    # grad_log_likelihood = torch.matmul(G,grad_ll.reshape(N_high**2,1)).reshape(N_high,N_high)
    
    # Grad prior
    difference = A_high.dot(z.cpu().data.numpy().reshape(N_high*N_high,1)) - b_high.reshape(N_high**2,1)
    # log_prior = - 0.5 * difference.T @ G_inverse @ difference
    # grad_log_prior = torch.autograd.grad(log_prior, z)[0]
    grad_log_prior = (- operator.dot(difference)).reshape(N_high,N_high)
    grad_log_prior = torch.tensor(grad_log_prior).to(torch.float32).to(device)
    
    # Random noise term
    W = torch.randn(*[N_high,N_high]).to(device)
    # random = torch.matmul(G_sqrt,W.reshape(N_high**2,1)).reshape(N_high,N_high)
    
    z = z + 0.5 * s ** 2 * grad_log_prior + 0.5 * s ** 2 * grad_ll + s * W
    # chains_evolution.append(z.cpu().data.numpy())

# %%
fig = plt.figure(figsize=(8,6))
ax1 = fig.add_subplot(121, projection='3d')
X, Y = np.meshgrid(x_high, y_high)
ax1.plot_wireframe(X, Y, z.cpu().data.numpy(),color='r')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('w')
ax1.set_title('SR')
ax2 = fig.add_subplot(122, projection='3d')
X, Y = np.meshgrid(x_high,y_high)
ax2.plot_wireframe(X, Y, w_high,color='r')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_zlabel('w')
ax2.set_title('high-res')
plt.show()

# %%
error1 = abs(w_high - z.cpu().data.numpy())
print('SR L2 Error:', (error1**2).sum()/error1.shape[0]**2)
# Out:
# SR L2 Error: 1.503122746578631e-05

# %% [markdown]
# #### Upscale by 6

# %%
N_low = 21
N_high = 121
scale = 6
a,b,c = 8,5,5

h_low = 1/(N_low-1)
x_low = np.arange(0,1.0001,h_low)
y_low = np.arange(0,1.0001,h_low)

h_high = 1/(N_high-1)
x_high = np.arange(0,1.0001,h_high)
y_high = np.arange(0,1.0001,h_high)

# %%
w_low, r_low, A_low, x_low, y_low = generate_data(N_low,a,b,c)
w_high, r_high, A_high, x_high, y_high = generate_data(N_high,a,b,c)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Parameters for RBF kernal
prior_sigma = 0.002
ll_sigma = 0.001

# %%
G = np.eye(N_high**2) * prior_sigma**2
G_inverse = np.eye(N_high**2) * (1/prior_sigma**2)

# Code downscaling matrix
H = np.zeros((N_low*N_low, N_high*N_high))

submatrix = np.zeros((N_low,N_high))
for i in range(N_low):
    submatrix[i,scale*i] = 1
    
for j in range(N_low):
    H[N_low*j:N_low*(j+1),N_high*scale*j:N_high*(scale*j+1)] = submatrix
    
# Turn matrices to tensors
G = torch.tensor(G).to(torch.float32).to(device)
G_inverse = torch.tensor(G_inverse).to(torch.float32).to(device)
H = torch.tensor(H).to(torch.float32).to(device)
A_high = torch.tensor(create_A(N_high)).to(torch.float32).to(device)
b_high = torch.tensor(create_forcing_term(N_high,a,b,c)).to(torch.float32).to(device)

# Store sparse matrices as sparse tensor
A_high = A_high.to_sparse()
H = H.to_sparse()
G = G.to_sparse()
G_inverse = G_inverse.to_sparse()
operator = torch.spmm(A_high.T,G_inverse).to(device)

# %%
x = torch.tensor(w_low).to(torch.float32).to(device)
posterior_initial = torch.randn(*[N_high,N_high]).to(torch.float32).to(device)

# %%
G = ResidualLearning().to(device)
G.load_state_dict(torch.load('models/train_NN/model3/21_121/lr0.01_gamma0.5/ckpt/best_model.pth')['netG'])
# Out:
# <All keys matched successfully>

# %%
# Parameters for Langevin dynamics
K = 4000
s = 0.0004

z = posterior_initial
chains_evolution = []
z = z.clone().detach().requires_grad_(True)
for i in range(K):
    # Grad log-likelihood
    observation = torch.spmm(H,z.reshape(N_high*N_high,1)).reshape(N_low,N_low)
    x_hat = observation + G(observation.reshape(1,N_low,N_low)).reshape(N_low,N_low)
    log_likelihood = (-1/(2*math.pow(ll_sigma, 2)) * torch.matmul((x-x_hat).reshape(1,N_low**2),(x-x_hat).reshape(N_low**2,1)))
    grad_ll = torch.autograd.grad(log_likelihood, z)[0]
    # grad_log_likelihood = torch.matmul(G,grad_ll.reshape(N_high**2,1)).reshape(N_high,N_high)
    
    # Grad prior
    difference = torch.spmm(A_high,z.reshape(N_high*N_high,1)) - b_high.reshape(N_high**2,1)
    # log_prior = - 0.5 * difference.T @ G_inverse @ difference
    # grad_log_prior = torch.autograd.grad(log_prior, z)[0]
    grad_log_prior = (- torch.spmm(operator,difference)).reshape(N_high,N_high)
    
    # Random noise term
    W = torch.randn(*[N_high,N_high]).to(device)
    # random = torch.matmul(G_sqrt,W.reshape(N_high**2,1)).reshape(N_high,N_high)
    
    z = z + 0.5 * s ** 2 * grad_log_prior + 0.5 * s ** 2 * grad_ll + s * W
    # chains_evolution.append(z.cpu().data.numpy())

# %%
fig = plt.figure(figsize=(8,6))
ax1 = fig.add_subplot(121, projection='3d')
X, Y = np.meshgrid(x_high, y_high)
ax1.plot_wireframe(X, Y, z.cpu().data.numpy(),color='r')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('w')
ax1.set_title('SR')
ax2 = fig.add_subplot(122, projection='3d')
X, Y = np.meshgrid(x_high,y_high)
ax2.plot_wireframe(X, Y, w_high,color='r')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_zlabel('w')
ax2.set_title('high-res')
plt.show()

# %%
error1 = abs(w_high - z.cpu().data.numpy())
print('SR L2 Error:', (error1**2).sum()/error1.shape[0]**2)
# Out:
# SR L2 Error: 3.480729715920515e-06

# %% [markdown]
# ### Model 4: Training $u_l = Hu_h + G(u_l)$

# %%
# Code downscaling matrix
N_low = 21
N_high = 121
scale = 6

H = np.zeros((N_low*N_low, N_high*N_high))

submatrix = np.zeros((N_low,N_high))
for i in range(N_low):
    submatrix[i,scale*i] = 1
    
for j in range(N_low):
    H[N_low*j:N_low*(j+1),N_high*scale*j:N_high*(scale*j+1)] = submatrix
    
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
H = torch.tensor(H).to(torch.float32).to(device)
H = H.to_sparse()

# %%
epoch_num = 400
batch_size = 8
lr = 0.01
gamma = 0.1

minimum_loss = float('inf')
loss_track = []

# Load training data
trainset = DataFromH5File3("data/DownBy6_21_121.h5",N_low,N_high,scale)
train_loader = data.DataLoader(dataset=trainset, batch_size=batch_size, shuffle=True)

# Initialise training model
G = ResidualLearning()
G.apply(weights_init_xavier).to(device)
mse = nn.MSELoss(reduction='sum')
optG = torch.optim.Adam(G.parameters(), lr = lr, weight_decay=0, betas=(0.5, 0.999))
r_scheduleG = torch.optim.lr_scheduler.StepLR(optG, step_size=100, gamma=gamma)

# Logger info
dir_name = f'models/model4/21_121/lr{lr}_gamma{gamma}'
makedir(dir_name)
logger = setup_logging('job0', dir_name, console=True)
logger.info(f'Training for {epoch_num} epoches and learning rate is {lr}')

for epoch in range(1, epoch_num+1):
    
    for i, d in enumerate(train_loader, 0):
        
        residual, observation, low_res = d
        size = residual.shape[0]
        residual = residual.to(device).reshape(size,1,N_low,N_low)
        observation = observation.to(device).reshape(size,1,N_low,N_low)
        low_res = low_res.to(device).reshape(size,1,N_low,N_low)
        
        optG.zero_grad()
        out = G(low_res)
        loss = mse(out,residual)/batch_size
        loss.backward()
        optG.step()
        
        if loss < minimum_loss:
            save_model(dir_name, epoch, 'best_model', r_scheduleG, G, optG)
            minimum_loss = loss
            
        if epoch%100 == 0:
            save_model(dir_name, epoch, 'model_epoch_{}'.format(epoch), r_scheduleG, G, optG)
            
        save_model(dir_name, epoch, 'current_epoch', r_scheduleG, G, optG)
            
        loss_track.append(loss.cpu().data.numpy())
        np.save(f'{dir_name}/chains/loss_curve.npy', np.array(loss_track))
        
        print("Epoch:", epoch, "Loss:", loss)

    r_scheduleG.step()
# Out:
# Output directory already exists
# 2024-05-31 15:10:15,843 : Training for 400 epoches and learning rate is 0.01
# Epoch: 1 Loss: tensor(9.9891, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 1 Loss: tensor(0.2982, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 1 Loss: tensor(0.5477, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 1 Loss: tensor(1.0286, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 1 Loss: tensor(0.4658, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 1 Loss: tensor(0.2896, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 1 Loss: tensor(0.1637, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 1 Loss: tensor(0.0952, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 1 Loss: tensor(0.1006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 1 Loss: tensor(0.0601, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 1 Loss: tensor(0.1646, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 1 Loss: tensor(0.1896, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 1 Loss: tensor(0.0552, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 1 Loss: tensor(0.0425, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 1 Loss: tensor(0.0287, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 1 Loss: tensor(0.0252, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 2 Loss: tensor(0.0363, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 2 Loss: tensor(0.0564, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 2 Loss: tensor(0.0200, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 2 Loss: tensor(0.0152, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 2 Loss: tensor(0.0484, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 2 Loss: tensor(0.0170, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 2 Loss: tensor(0.0190, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 2 Loss: tensor(0.0140, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 2 Loss: tensor(0.0140, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 2 Loss: tensor(0.0135, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 2 Loss: tensor(0.0491, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 2 Loss: tensor(0.0268, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 2 Loss: tensor(0.0173, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 2 Loss: tensor(0.0188, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 2 Loss: tensor(0.0171, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 2 Loss: tensor(0.0097, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 3 Loss: tensor(0.0140, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 3 Loss: tensor(0.0167, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 3 Loss: tensor(0.0107, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 3 Loss: tensor(0.0324, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 3 Loss: tensor(0.0098, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 3 Loss: tensor(0.0178, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 3 Loss: tensor(0.0170, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 3 Loss: tensor(0.0173, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 3 Loss: tensor(0.0085, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 3 Loss: tensor(0.0073, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 3 Loss: tensor(0.0098, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 3 Loss: tensor(0.0084, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 3 Loss: tensor(0.0064, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 3 Loss: tensor(0.0104, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 3 Loss: tensor(0.0066, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 3 Loss: tensor(0.0066, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 4 Loss: tensor(0.0083, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 4 Loss: tensor(0.0141, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 4 Loss: tensor(0.0307, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 4 Loss: tensor(0.0135, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 4 Loss: tensor(0.0099, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 4 Loss: tensor(0.0075, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 4 Loss: tensor(0.0138, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 4 Loss: tensor(0.0053, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 4 Loss: tensor(0.0063, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 4 Loss: tensor(0.0051, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 4 Loss: tensor(0.0079, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 4 Loss: tensor(0.0082, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 4 Loss: tensor(0.0049, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 4 Loss: tensor(0.0059, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 4 Loss: tensor(0.0105, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 4 Loss: tensor(0.0077, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 5 Loss: tensor(0.0115, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 5 Loss: tensor(0.0109, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 5 Loss: tensor(0.0059, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 5 Loss: tensor(0.0149, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 5 Loss: tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 5 Loss: tensor(0.0069, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 5 Loss: tensor(0.0093, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 5 Loss: tensor(0.0072, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 5 Loss: tensor(0.0088, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 5 Loss: tensor(0.0078, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 5 Loss: tensor(0.0085, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 5 Loss: tensor(0.0071, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 5 Loss: tensor(0.0085, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 5 Loss: tensor(0.0086, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 5 Loss: tensor(0.0054, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 5 Loss: tensor(0.0075, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 6 Loss: tensor(0.0058, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 6 Loss: tensor(0.0046, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 6 Loss: tensor(0.0046, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 6 Loss: tensor(0.0056, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 6 Loss: tensor(0.0054, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 6 Loss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 6 Loss: tensor(0.0065, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 6 Loss: tensor(0.0100, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 6 Loss: tensor(0.0091, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 6 Loss: tensor(0.0061, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 6 Loss: tensor(0.0138, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 6 Loss: tensor(0.0152, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 6 Loss: tensor(0.0179, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 6 Loss: tensor(0.0093, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 6 Loss: tensor(0.0062, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 6 Loss: tensor(0.0082, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 7 Loss: tensor(0.0113, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 7 Loss: tensor(0.0128, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 7 Loss: tensor(0.0215, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 7 Loss: tensor(0.0140, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 7 Loss: tensor(0.0136, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 7 Loss: tensor(0.0074, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 7 Loss: tensor(0.0087, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 7 Loss: tensor(0.0124, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 7 Loss: tensor(0.0121, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 7 Loss: tensor(0.0140, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 7 Loss: tensor(0.0167, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 7 Loss: tensor(0.0125, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 7 Loss: tensor(0.0103, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 7 Loss: tensor(0.0063, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 7 Loss: tensor(0.0068, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 7 Loss: tensor(0.0070, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 8 Loss: tensor(0.0048, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 8 Loss: tensor(0.0048, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 8 Loss: tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 8 Loss: tensor(0.0052, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 8 Loss: tensor(0.0063, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 8 Loss: tensor(0.0036, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 8 Loss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 8 Loss: tensor(0.0051, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 8 Loss: tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 8 Loss: tensor(0.0064, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 8 Loss: tensor(0.0090, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 8 Loss: tensor(0.0073, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 8 Loss: tensor(0.0078, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 8 Loss: tensor(0.0044, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 8 Loss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 8 Loss: tensor(0.0052, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 9 Loss: tensor(0.0045, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 9 Loss: tensor(0.0053, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 9 Loss: tensor(0.0057, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 9 Loss: tensor(0.0044, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 9 Loss: tensor(0.0080, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 9 Loss: tensor(0.0068, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 9 Loss: tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 9 Loss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 9 Loss: tensor(0.0082, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 9 Loss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 9 Loss: tensor(0.0061, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 9 Loss: tensor(0.0038, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 9 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 9 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 9 Loss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 9 Loss: tensor(0.0056, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 10 Loss: tensor(0.0088, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 10 Loss: tensor(0.0057, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 10 Loss: tensor(0.0048, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 10 Loss: tensor(0.0046, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 10 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 10 Loss: tensor(0.0059, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 10 Loss: tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 10 Loss: tensor(0.0038, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 10 Loss: tensor(0.0036, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 10 Loss: tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 10 Loss: tensor(0.0051, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 10 Loss: tensor(0.0083, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 10 Loss: tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 10 Loss: tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 10 Loss: tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 10 Loss: tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 11 Loss: tensor(0.0044, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 11 Loss: tensor(0.0057, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 11 Loss: tensor(0.0053, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 11 Loss: tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 11 Loss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 11 Loss: tensor(0.0077, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 11 Loss: tensor(0.0047, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 11 Loss: tensor(0.0073, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 11 Loss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 11 Loss: tensor(0.0060, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 11 Loss: tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 11 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 11 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 11 Loss: tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 11 Loss: tensor(0.0054, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 11 Loss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 12 Loss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 12 Loss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 12 Loss: tensor(0.0052, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 12 Loss: tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 12 Loss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 12 Loss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 12 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 12 Loss: tensor(0.0046, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 12 Loss: tensor(0.0082, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 12 Loss: tensor(0.0076, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 12 Loss: tensor(0.0058, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 12 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 12 Loss: tensor(0.0062, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 12 Loss: tensor(0.0065, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 12 Loss: tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 12 Loss: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 13 Loss: tensor(0.0078, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 13 Loss: tensor(0.0047, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 13 Loss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 13 Loss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 13 Loss: tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 13 Loss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 13 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 13 Loss: tensor(0.0048, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 13 Loss: tensor(0.0080, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 13 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 13 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 13 Loss: tensor(0.0048, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 13 Loss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 13 Loss: tensor(0.0048, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 13 Loss: tensor(0.0060, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 13 Loss: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 14 Loss: tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 14 Loss: tensor(0.0055, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 14 Loss: tensor(0.0052, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 14 Loss: tensor(0.0059, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 14 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 14 Loss: tensor(0.0054, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 14 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 14 Loss: tensor(0.0046, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 14 Loss: tensor(0.0054, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 14 Loss: tensor(0.0047, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 14 Loss: tensor(0.0053, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 14 Loss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 14 Loss: tensor(0.0051, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 14 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 14 Loss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 14 Loss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 15 Loss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 15 Loss: tensor(0.0074, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 15 Loss: tensor(0.0074, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 15 Loss: tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 15 Loss: tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 15 Loss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 15 Loss: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 15 Loss: tensor(0.0045, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 15 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 15 Loss: tensor(0.0051, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 15 Loss: tensor(0.0046, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 15 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 15 Loss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 15 Loss: tensor(0.0051, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 15 Loss: tensor(0.0046, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 15 Loss: tensor(0.0036, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 16 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 16 Loss: tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 16 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 16 Loss: tensor(0.0044, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 16 Loss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 16 Loss: tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 16 Loss: tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 16 Loss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 16 Loss: tensor(0.0048, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 16 Loss: tensor(0.0062, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 16 Loss: tensor(0.0036, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 16 Loss: tensor(0.0069, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 16 Loss: tensor(0.0108, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 16 Loss: tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 16 Loss: tensor(0.0054, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 16 Loss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 17 Loss: tensor(0.0070, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 17 Loss: tensor(0.0047, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 17 Loss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 17 Loss: tensor(0.0038, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 17 Loss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 17 Loss: tensor(0.0055, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 17 Loss: tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 17 Loss: tensor(0.0045, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 17 Loss: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 17 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 17 Loss: tensor(0.0073, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 17 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 17 Loss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 17 Loss: tensor(0.0064, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 17 Loss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 17 Loss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 18 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 18 Loss: tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 18 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 18 Loss: tensor(0.0053, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 18 Loss: tensor(0.0091, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 18 Loss: tensor(0.0067, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 18 Loss: tensor(0.0088, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 18 Loss: tensor(0.0178, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 18 Loss: tensor(0.0205, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 18 Loss: tensor(0.0183, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 18 Loss: tensor(0.0192, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 18 Loss: tensor(0.0174, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 18 Loss: tensor(0.0177, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 18 Loss: tensor(0.0158, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 18 Loss: tensor(0.0137, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 18 Loss: tensor(0.0101, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 19 Loss: tensor(0.0088, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 19 Loss: tensor(0.0101, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 19 Loss: tensor(0.0110, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 19 Loss: tensor(0.0123, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 19 Loss: tensor(0.0106, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 19 Loss: tensor(0.0349, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 19 Loss: tensor(0.0074, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 19 Loss: tensor(0.0128, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 19 Loss: tensor(0.0095, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 19 Loss: tensor(0.0137, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 19 Loss: tensor(0.0111, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 19 Loss: tensor(0.0096, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 19 Loss: tensor(0.0112, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 19 Loss: tensor(0.0177, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 19 Loss: tensor(0.0249, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 19 Loss: tensor(0.0140, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 20 Loss: tensor(0.0114, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 20 Loss: tensor(0.0129, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 20 Loss: tensor(0.0113, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 20 Loss: tensor(0.0108, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 20 Loss: tensor(0.0068, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 20 Loss: tensor(0.0067, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 20 Loss: tensor(0.0094, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 20 Loss: tensor(0.0076, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 20 Loss: tensor(0.0110, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 20 Loss: tensor(0.0066, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 20 Loss: tensor(0.0096, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 20 Loss: tensor(0.0070, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 20 Loss: tensor(0.0119, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 20 Loss: tensor(0.0073, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 20 Loss: tensor(0.0126, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 20 Loss: tensor(0.0129, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 21 Loss: tensor(0.0136, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 21 Loss: tensor(0.0076, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 21 Loss: tensor(0.0076, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 21 Loss: tensor(0.0107, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 21 Loss: tensor(0.0085, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 21 Loss: tensor(0.0092, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 21 Loss: tensor(0.0072, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 21 Loss: tensor(0.0053, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 21 Loss: tensor(0.0063, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 21 Loss: tensor(0.0072, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 21 Loss: tensor(0.0086, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 21 Loss: tensor(0.0088, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 21 Loss: tensor(0.0080, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 21 Loss: tensor(0.0075, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 21 Loss: tensor(0.0059, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 21 Loss: tensor(0.0065, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 22 Loss: tensor(0.0060, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 22 Loss: tensor(0.0067, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 22 Loss: tensor(0.0103, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 22 Loss: tensor(0.0075, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 22 Loss: tensor(0.0056, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 22 Loss: tensor(0.0038, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 22 Loss: tensor(0.0086, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 22 Loss: tensor(0.0055, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 22 Loss: tensor(0.0044, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 22 Loss: tensor(0.0074, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 22 Loss: tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 22 Loss: tensor(0.0051, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 22 Loss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 22 Loss: tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 22 Loss: tensor(0.0056, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 22 Loss: tensor(0.0049, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 23 Loss: tensor(0.0058, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 23 Loss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 23 Loss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 23 Loss: tensor(0.0052, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 23 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 23 Loss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 23 Loss: tensor(0.0059, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 23 Loss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 23 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 23 Loss: tensor(0.0071, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 23 Loss: tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 23 Loss: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 23 Loss: tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 23 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 23 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 23 Loss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 24 Loss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 24 Loss: tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 24 Loss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 24 Loss: tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 24 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 24 Loss: tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 24 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 24 Loss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 24 Loss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 24 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 24 Loss: tensor(0.0048, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 24 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 24 Loss: tensor(0.0056, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 24 Loss: tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 24 Loss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 24 Loss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 25 Loss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 25 Loss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 25 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 25 Loss: tensor(0.0036, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 25 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 25 Loss: tensor(0.0049, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 25 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 25 Loss: tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 25 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 25 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 25 Loss: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 25 Loss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 25 Loss: tensor(0.0053, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 25 Loss: tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 25 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 25 Loss: tensor(0.0053, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 26 Loss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 26 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 26 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 26 Loss: tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 26 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 26 Loss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 26 Loss: tensor(0.0058, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 26 Loss: tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 26 Loss: tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 26 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 26 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 26 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 26 Loss: tensor(0.0059, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 26 Loss: tensor(0.0052, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 26 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 26 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 27 Loss: tensor(0.0055, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 27 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 27 Loss: tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 27 Loss: tensor(0.0036, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 27 Loss: tensor(0.0057, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 27 Loss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 27 Loss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 27 Loss: tensor(0.0049, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 27 Loss: tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 27 Loss: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 27 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 27 Loss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 27 Loss: tensor(0.0044, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 27 Loss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 27 Loss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 27 Loss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 28 Loss: tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 28 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 28 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 28 Loss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 28 Loss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 28 Loss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 28 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 28 Loss: tensor(0.0053, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 28 Loss: tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 28 Loss: tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 28 Loss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 28 Loss: tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 28 Loss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 28 Loss: tensor(0.0044, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 28 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 28 Loss: tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 29 Loss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 29 Loss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 29 Loss: tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 29 Loss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 29 Loss: tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 29 Loss: tensor(0.0064, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 29 Loss: tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 29 Loss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 29 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 29 Loss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 29 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 29 Loss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 29 Loss: tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 29 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 29 Loss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 29 Loss: tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 30 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 30 Loss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 30 Loss: tensor(0.0046, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 30 Loss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 30 Loss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 30 Loss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 30 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 30 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 30 Loss: tensor(0.0047, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 30 Loss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 30 Loss: tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 30 Loss: tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 30 Loss: tensor(0.0038, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 30 Loss: tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 30 Loss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 30 Loss: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 31 Loss: tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 31 Loss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 31 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 31 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 31 Loss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 31 Loss: tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 31 Loss: tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 31 Loss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 31 Loss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 31 Loss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 31 Loss: tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 31 Loss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 31 Loss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 31 Loss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 31 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 31 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 32 Loss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 32 Loss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 32 Loss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 32 Loss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 32 Loss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 32 Loss: tensor(0.0038, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 32 Loss: tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 32 Loss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 32 Loss: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 32 Loss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 32 Loss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 32 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 32 Loss: tensor(0.0036, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 32 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 32 Loss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 32 Loss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 33 Loss: tensor(0.0036, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 33 Loss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 33 Loss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 33 Loss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 33 Loss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 33 Loss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 33 Loss: tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 33 Loss: tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 33 Loss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 33 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 33 Loss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 33 Loss: tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 33 Loss: tensor(0.0057, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 33 Loss: tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 33 Loss: tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 33 Loss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 34 Loss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 34 Loss: tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 34 Loss: tensor(0.0044, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 34 Loss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 34 Loss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 34 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 34 Loss: tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 34 Loss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 34 Loss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 34 Loss: tensor(0.0038, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 34 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 34 Loss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 34 Loss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 34 Loss: tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 34 Loss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 34 Loss: tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 35 Loss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 35 Loss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 35 Loss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 35 Loss: tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 35 Loss: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 35 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 35 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 35 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 35 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 35 Loss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 35 Loss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 35 Loss: tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 35 Loss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 35 Loss: tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 35 Loss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 35 Loss: tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 36 Loss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 36 Loss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 36 Loss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 36 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 36 Loss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 36 Loss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 36 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 36 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 36 Loss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 36 Loss: tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 36 Loss: tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 36 Loss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 36 Loss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 36 Loss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 36 Loss: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 36 Loss: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 37 Loss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 37 Loss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 37 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 37 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 37 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 37 Loss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 37 Loss: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 37 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 37 Loss: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 37 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 37 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 37 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 37 Loss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 37 Loss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 37 Loss: tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 37 Loss: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 38 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 38 Loss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 38 Loss: tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 38 Loss: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 38 Loss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 38 Loss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 38 Loss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 38 Loss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 38 Loss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 38 Loss: tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 38 Loss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 38 Loss: tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 38 Loss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 38 Loss: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 38 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 38 Loss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 39 Loss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 39 Loss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 39 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 39 Loss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 39 Loss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 39 Loss: tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 39 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 39 Loss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 39 Loss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 39 Loss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 39 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 39 Loss: tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 39 Loss: tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 39 Loss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 39 Loss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 39 Loss: tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 40 Loss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 40 Loss: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 40 Loss: tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 40 Loss: tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 40 Loss: tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 40 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 40 Loss: tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 40 Loss: tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 40 Loss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 40 Loss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 40 Loss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 40 Loss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 40 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 40 Loss: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 40 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 40 Loss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 41 Loss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 41 Loss: tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 41 Loss: tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 41 Loss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 41 Loss: tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 41 Loss: tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 41 Loss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 41 Loss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 41 Loss: tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 41 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 41 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 41 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 41 Loss: tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 41 Loss: tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 41 Loss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 41 Loss: tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 42 Loss: tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 42 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 42 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 42 Loss: tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 42 Loss: tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 42 Loss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 42 Loss: tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 42 Loss: tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 42 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 42 Loss: tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 42 Loss: tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# ...
# Epoch: 387 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 387 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 387 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 387 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 387 Loss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 387 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 387 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 387 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 387 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 387 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 387 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 388 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 388 Loss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 388 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 388 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 388 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 388 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 388 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 388 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 388 Loss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 388 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 388 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 388 Loss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 388 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 388 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 388 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 388 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 389 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 389 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 389 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 389 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 389 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 389 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 389 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 389 Loss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 389 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 389 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 389 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 389 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 389 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 389 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 389 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 389 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 390 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 390 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 390 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 390 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 390 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 390 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 390 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 390 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 390 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 390 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 390 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 390 Loss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 390 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 390 Loss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 390 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 390 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 391 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 391 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 391 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 391 Loss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 391 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 391 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 391 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 391 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 391 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 391 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 391 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 391 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 391 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 391 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 391 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 391 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 392 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 392 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 392 Loss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 392 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 392 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 392 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 392 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 392 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 392 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 392 Loss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 392 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 392 Loss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 392 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 392 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 392 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 392 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 393 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 393 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 393 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 393 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 393 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 393 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 393 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 393 Loss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 393 Loss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 393 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 393 Loss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 393 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 393 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 393 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 393 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 393 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 394 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 394 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 394 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 394 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 394 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 394 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 394 Loss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 394 Loss: tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 394 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 394 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 394 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 394 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 394 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 394 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 394 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 394 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 395 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 395 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 395 Loss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 395 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 395 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 395 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 395 Loss: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 395 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 395 Loss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 395 Loss: tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 395 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 395 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 395 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 395 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 395 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 395 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 396 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 396 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 396 Loss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 396 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 396 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 396 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 396 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 396 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 396 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 396 Loss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 396 Loss: tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 396 Loss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 396 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 396 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 396 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 396 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 397 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 397 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 397 Loss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 397 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 397 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 397 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 397 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 397 Loss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 397 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 397 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 397 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 397 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 397 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 397 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 397 Loss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 397 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 398 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 398 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 398 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 398 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 398 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 398 Loss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 398 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 398 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 398 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 398 Loss: tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 398 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 398 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 398 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 398 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 398 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 398 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 399 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 399 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 399 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 399 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 399 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 399 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 399 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 399 Loss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 399 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 399 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 399 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 399 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 399 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 399 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 399 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 399 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 400 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 400 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 400 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 400 Loss: tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 400 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 400 Loss: tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 400 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 400 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 400 Loss: tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 400 Loss: tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 400 Loss: tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 400 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 400 Loss: tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 400 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 400 Loss: tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch: 400 Loss: tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)

# %%
N_low = 21
N_high = 121
scale = 6
a, b, c = 8,3,5

h_low = 1/(N_low-1)
x_low = np.arange(0,1.0001,h_low)
y_low = np.arange(0,1.0001,h_low)

h_high = 1/(N_high-1)
x_high = np.arange(0,1.0001,h_high)
y_high = np.arange(0,1.0001,h_high)

# %%
w_low, r_low, A_low, x_low, y_low = generate_data(N_low,a,b,c)
w_high, r_high, A_high, x_high, y_high = generate_data(N_high,a,b,c)

# Code downscaling matrix
H = np.zeros((N_low*N_low, N_high*N_high))

submatrix = np.zeros((N_low,N_high))
for i in range(N_low):
    submatrix[i,scale*i] = 1
    
for j in range(N_low):
    H[N_low*j:N_low*(j+1),N_high*scale*j:N_high*(scale*j+1)] = submatrix

# %%
G = ResidualLearning().to(device)
G.load_state_dict(torch.load('models/model4/21_121/lr0.01_gamma0.1/ckpt/best_model.pth')['netG'])
# G.load_state_dict(torch.load('models/model4/21_121/lr0.01_gamma0.1/ckpt/current_epoch.pth')['netG'])
# Out:
# <All keys matched successfully>

# %%
out = G(torch.tensor(w_low).to(device).reshape(1,1,N_low,N_low).to(torch.float32))

# %%
residual = w_low-(H@w_high.reshape(N_high*N_high)).reshape(N_low,N_low)

# %%
fig = plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
plt.pcolormesh(x_low, y_low, residual, cmap='rainbow')
cbar = plt.colorbar(pad=0.05, aspect=10)
cbar.mappable.set_clim(-0.03, 0.03)
plt.title('LR')
plt.xlabel('x')
plt.ylabel('y')
plt.subplot(1,2,2)
plt.pcolormesh(x_low, y_low, out.cpu().data.numpy()[0][0], cmap='rainbow')
cbar = plt.colorbar(pad=0.05, aspect=10)
cbar.mappable.set_clim(-0.03, 0.03)
plt.title('LR')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ### Upscale by 6

# %%
N_low = 21
N_high = 121
scale = 6
a,b,c = 8,5,5

h_low = 1/(N_low-1)
x_low = np.arange(0,1.0001,h_low)
y_low = np.arange(0,1.0001,h_low)

h_high = 1/(N_high-1)
x_high = np.arange(0,1.0001,h_high)
y_high = np.arange(0,1.0001,h_high)

# %%
w_low, r_low, A_low, x_low, y_low = generate_data(N_low,a,b,c)
w_high, r_high, A_high, x_high, y_high = generate_data(N_high,a,b,c)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Parameters for RBF kernal
prior_sigma = 0.002
ll_sigma = 0.001

# %%
G = np.eye(N_high**2) * prior_sigma**2
G_inverse = np.eye(N_high**2) * (1/prior_sigma**2)

# Code downscaling matrix
H = np.zeros((N_low*N_low, N_high*N_high))

submatrix = np.zeros((N_low,N_high))
for i in range(N_low):
    submatrix[i,scale*i] = 1
    
for j in range(N_low):
    H[N_low*j:N_low*(j+1),N_high*scale*j:N_high*(scale*j+1)] = submatrix
    
# Turn matrices to tensors
G = torch.tensor(G).to(torch.float32).to(device)
G_inverse = torch.tensor(G_inverse).to(torch.float32).to(device)
H = torch.tensor(H).to(torch.float32).to(device)
A_high = torch.tensor(create_A(N_high)).to(torch.float32).to(device)
b_high = torch.tensor(create_forcing_term(N_high,a,b,c)).to(torch.float32).to(device)

# Store sparse matrices as sparse tensor
A_high = A_high.to_sparse()
H = H.to_sparse()
G = G.to_sparse()
G_inverse = G_inverse.to_sparse()
operator = torch.spmm(A_high.T,G_inverse).to(device)

# %%
x = torch.tensor(w_low).to(torch.float32).to(device)
posterior_initial = torch.randn(*[N_high,N_high]).to(torch.float32).to(device)

# %%
G = ResidualLearning().to(device)
G.load_state_dict(torch.load('models/train_NN/model3/21_121/lr0.01_gamma0.5/ckpt/best_model.pth')['netG'])
# Out:
# <All keys matched successfully>

# %%
# Parameters for Langevin dynamics
K = 4000
s = 0.0004

z = posterior_initial
chains_evolution = []
z = z.clone().detach().requires_grad_(True)
for i in range(K):
    # Grad log-likelihood
    observation = torch.spmm(H,z.reshape(N_high*N_high,1)).reshape(N_low,N_low)
    x_hat = observation + G(observation.reshape(1,N_low,N_low)).reshape(N_low,N_low)
    log_likelihood = (-1/(2*math.pow(ll_sigma, 2)) * torch.matmul((x-x_hat).reshape(1,N_low**2),(x-x_hat).reshape(N_low**2,1)))
    grad_ll = torch.autograd.grad(log_likelihood, z)[0]
    # grad_log_likelihood = torch.matmul(G,grad_ll.reshape(N_high**2,1)).reshape(N_high,N_high)
    
    # Grad prior
    difference = torch.spmm(A_high,z.reshape(N_high*N_high,1)) - b_high.reshape(N_high**2,1)
    # log_prior = - 0.5 * difference.T @ G_inverse @ difference
    # grad_log_prior = torch.autograd.grad(log_prior, z)[0]
    grad_log_prior = (- torch.spmm(operator,difference)).reshape(N_high,N_high)
    
    # Random noise term
    W = torch.randn(*[N_high,N_high]).to(device)
    # random = torch.matmul(G_sqrt,W.reshape(N_high**2,1)).reshape(N_high,N_high)
    
    z = z + 0.5 * s ** 2 * grad_log_prior + 0.5 * s ** 2 * grad_ll + s * W
    # chains_evolution.append(z.cpu().data.numpy())

# %%
fig = plt.figure(figsize=(8,6))
ax1 = fig.add_subplot(121, projection='3d')
X, Y = np.meshgrid(x_high, y_high)
ax1.plot_wireframe(X, Y, z.cpu().data.numpy(),color='r')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('w')
ax1.set_title('SR')
ax2 = fig.add_subplot(122, projection='3d')
X, Y = np.meshgrid(x_high,y_high)
ax2.plot_wireframe(X, Y, w_high,color='r')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_zlabel('w')
ax2.set_title('high-res')
plt.show()

# %%
error1 = abs(w_high - z.cpu().data.numpy())
print('SR L2 Error:', (error1**2).sum()/error1.shape[0]**2)
# Out:
# SR L2 Error: 3.480729715920515e-06
